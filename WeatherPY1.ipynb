# %%
#Analysis based on Information Dated December 2020
#What's the weather like as we approach the equator?

#Trend 1 : Sample cities near the equator are likely to have higher maximum temperature (between 70 and 90 degrees). Sample cities between -20 and 20 latitudes are likely to have higher maximum temperatures than those that are not. Sample cities are more likely to have lower maximum temperature as (1) latitude decreases from -20 and (2) latitude increases from 20.
#Trend 2 : There seems to be little correlation between cloudiness and windspeed and distance from the equator (i.e., latitude) for the sample cities. Also note that sample cities' wind speed seem to be concentrated between 0 and 10 mph.
#Trend 3 : Sample cities near the equator are likely to have higher humidity (between 60 and 100%). Also note that sample cities between 40 and 80 latitude tend to have high humidity (between 70% and 100%).

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm

# Import API key
from api_key import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %%
# Create DataFrame
cities_df = pd.DataFrame({"City": cities})

# Create columns in DataFrame
cities_df["Cloudiness"] = ""
cities_df["Country"] = ""
cities_df["Date"] = ""
cities_df["Humidity"] = ""
cities_df["Lat"] = ""
cities_df["Lng"] = ""
cities_df["Max Temp"] = ""
cities_df["Wind Speed"] = ""

print("Beginning Data Retrieval")
print ("--------------------------------")
#set counters for printing status
counter = 1
max_counter = len(cities_df["City"])

# Create settings dictionary with information we're interested in
settings = {"units": "imperial", "appid": weather_api_key}

# Loop through the cities_df and run a search for each city for the columns
for index, row in cities_df.iterrows():
    city = row['City']
    print(f"Processing Record {counter} of {max_counter} | {city}")
    counter = counter + 1
    try:
        current_weather = owm.get_current(city, **settings)
        cities_df.loc[index, "Cloudiness"] = current_weather['clouds']['all']
        cities_df.loc[index, "Country"] = current_weather['sys']['country']
        cities_df.loc[index, "Date"] = current_weather['dt']
        cities_df.loc[index, "Humidity"] = current_weather['main']['humidity']
        cities_df.loc[index, "Lat"] = current_weather['coord']['lat']
        cities_df.loc[index, "Lng"] = current_weather['coord']['lon']
        cities_df.loc[index, "Max Temp"] = current_weather['main']["temp_max"]
        cities_df.loc[index, "Wind Speed"] = current_weather['wind']["speed"]        
    except:
        print ("City not found. Skipping...")
    
    time.sleep(0.5)
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of 600 | saskylakh
# Processing Record 2 of 600 | hithadhoo
# Processing Record 3 of 600 | punta arenas
# Processing Record 4 of 600 | ostrovnoy
# Processing Record 5 of 600 | suoyarvi
# Processing Record 6 of 600 | mount isa
# Processing Record 7 of 600 | albany
# Processing Record 8 of 600 | rikitea
# Processing Record 9 of 600 | lata
# Processing Record 10 of 600 | leningradskiy
# Processing Record 11 of 600 | port-gentil
# Processing Record 12 of 600 | provideniya
# Processing Record 13 of 600 | arraial do cabo
# Processing Record 14 of 600 | batemans bay
# Processing Record 15 of 600 | taolanaro
# City not found. Skipping...
# Processing Record 16 of 600 | barrow
# Processing Record 17 of 600 | zhanaozen
# Processing Record 18 of 600 | bubaque
# Processing Record 19 of 600 | hermanus
# Processing Record 20 of 600 | lagoa
# Processing Record 21 of 600 | busselton
# Processing Record 22 of 600 | caiaponia
# Processing Record 23 of 600 | alpena
# Processing Record 24 of 600 | mataura
# Processing Record 25 of 600 | tuatapere
# Processing Record 26 of 600 | chumikan
# Processing Record 27 of 600 | kruisfontein
# Processing Record 28 of 600 | nanortalik
# Processing Record 29 of 600 | atuona
# Processing Record 30 of 600 | barentsburg
# City not found. Skipping...
# Processing Record 31 of 600 | vaini
# Processing Record 32 of 600 | saint george
# Processing Record 33 of 600 | hobart
# Processing Record 34 of 600 | jamestown
# Processing Record 35 of 600 | bethel
# Processing Record 36 of 600 | roma
# Processing Record 37 of 600 | margate
# Processing Record 38 of 600 | dandong
# Processing Record 39 of 600 | dikson
# Processing Record 40 of 600 | viru
# Processing Record 41 of 600 | new norfolk
# Processing Record 42 of 600 | severo-kurilsk
# Processing Record 43 of 600 | longyearbyen
# Processing Record 44 of 600 | tecoanapa
# Processing Record 45 of 600 | quartucciu
# Processing Record 46 of 600 | cosautlan
# Processing Record 47 of 600 | ancud
# Processing Record 48 of 600 | san patricio
# Processing Record 49 of 600 | soyo
# Processing Record 50 of 600 | mocambique
# City not found. Skipping...
# Processing Record 51 of 600 | hilo
# Processing Record 52 of 600 | portland
# Processing Record 53 of 600 | ushuaia
# Processing Record 54 of 600 | devarkonda
# Processing Record 55 of 600 | lebu
# Processing Record 56 of 600 | mangrol
# Processing Record 57 of 600 | mikhaylovka
# Processing Record 58 of 600 | half moon bay
# Processing Record 59 of 600 | chandbali
# Processing Record 60 of 600 | torbay
# Processing Record 61 of 600 | palana
# Processing Record 62 of 600 | cherskiy
# Processing Record 63 of 600 | mar del plata
# Processing Record 64 of 600 | talnakh
# Processing Record 65 of 600 | east london
# Processing Record 66 of 600 | barreiras
# Processing Record 67 of 600 | kapaa
# Processing Record 68 of 600 | naze
# Processing Record 69 of 600 | victoria
# Processing Record 70 of 600 | korla
# Processing Record 71 of 600 | norman wells
# Processing Record 72 of 600 | santa quiteria
# Processing Record 73 of 600 | mrirt
# City not found. Skipping...
# Processing Record 74 of 600 | tuggurt
# City not found. Skipping...
# Processing Record 75 of 600 | biskamzha
# Processing Record 76 of 600 | saint-philippe
# Processing Record 77 of 600 | pisco
# Processing Record 78 of 600 | nikolskoye
# Processing Record 79 of 600 | oranjemund
# Processing Record 80 of 600 | ossora
# Processing Record 81 of 600 | alice springs
# Processing Record 82 of 600 | vorukh
# Processing Record 83 of 600 | teknaf
# Processing Record 84 of 600 | kapoeta
# Processing Record 85 of 600 | bengkulu
# Processing Record 86 of 600 | katsuura
# Processing Record 87 of 600 | inirida
# Processing Record 88 of 600 | cape town
# Processing Record 89 of 600 | ramanuj ganj
# Processing Record 90 of 600 | uruacu
# Processing Record 91 of 600 | zhigansk
# Processing Record 92 of 600 | cayenne
# Processing Record 93 of 600 | asau
# Processing Record 94 of 600 | lompoc
# Processing Record 95 of 600 | ketchenery
# City not found. Skipping...
# Processing Record 96 of 600 | harper
# Processing Record 97 of 600 | kayankulam
# Processing Record 98 of 600 | bredasdorp
# Processing Record 99 of 600 | hasaki
# Processing Record 100 of 600 | mugur-aksy
# Processing Record 101 of 600 | comodoro rivadavia
# Processing Record 102 of 600 | bambous virieux
# Processing Record 103 of 600 | abu dhabi
# Processing Record 104 of 600 | vostok
# Processing Record 105 of 600 | port alfred
# Processing Record 106 of 600 | mogadishu
# Processing Record 107 of 600 | yellowknife
# Processing Record 108 of 600 | vaitupu
# City not found. Skipping...
# Processing Record 109 of 600 | souillac
# Processing Record 110 of 600 | tuktoyaktuk
# Processing Record 111 of 600 | geraldton
# Processing Record 112 of 600 | port elizabeth
# Processing Record 113 of 600 | manokwari
# Processing Record 114 of 600 | mys shmidta
# City not found. Skipping...
# Processing Record 115 of 600 | takoradi
# Processing Record 116 of 600 | fort nelson
# Processing Record 117 of 600 | college
# Processing Record 118 of 600 | iqaluit
# Processing Record 119 of 600 | sainte-anne-des-monts
# Processing Record 120 of 600 | krasnoselkup
# Processing Record 121 of 600 | burgersdorp
# Processing Record 122 of 600 | bataipora
# Processing Record 123 of 600 | beysehir
# Processing Record 124 of 600 | eugene
# Processing Record 125 of 600 | samusu
# City not found. Skipping...
# Processing Record 126 of 600 | los llanos de aridane
# Processing Record 127 of 600 | palic
# Processing Record 128 of 600 | sao pedro do sul
# Processing Record 129 of 600 | savannah bight
# Processing Record 130 of 600 | acapulco
# Processing Record 131 of 600 | necochea
# Processing Record 132 of 600 | avarua
# Processing Record 133 of 600 | carnarvon
# Processing Record 134 of 600 | povenets
# Processing Record 135 of 600 | chapais
# Processing Record 136 of 600 | saint-augustin
# Processing Record 137 of 600 | quchan
# Processing Record 138 of 600 | qaanaaq
# Processing Record 139 of 600 | kumluca
# Processing Record 140 of 600 | haines junction
# Processing Record 141 of 600 | bonavista
# Processing Record 142 of 600 | nemuro
# Processing Record 143 of 600 | adrar
# Processing Record 144 of 600 | puerto escondido
# Processing Record 145 of 600 | jinchengjiang
# City not found. Skipping...
# Processing Record 146 of 600 | upernavik
# Processing Record 147 of 600 | belushya guba
# City not found. Skipping...
# Processing Record 148 of 600 | sabha
# Processing Record 149 of 600 | aswan
# Processing Record 150 of 600 | nizhniy baskunchak
# Processing Record 151 of 600 | hualmay
# Processing Record 152 of 600 | tulle
# Processing Record 153 of 600 | castro
# Processing Record 154 of 600 | kloulklubed
# Processing Record 155 of 600 | artyk
# City not found. Skipping...
# Processing Record 156 of 600 | mehamn
# Processing Record 157 of 600 | destin
# Processing Record 158 of 600 | shache
# Processing Record 159 of 600 | labuhan
# Processing Record 160 of 600 | victor harbor
# Processing Record 161 of 600 | sambava
# Processing Record 162 of 600 | muscat
# Processing Record 163 of 600 | ignacio zaragoza
# Processing Record 164 of 600 | oktyabrskoye
# Processing Record 165 of 600 | ganzhou
# Processing Record 166 of 600 | rio grande
# Processing Record 167 of 600 | lulea
# Processing Record 168 of 600 | kodiak
# Processing Record 169 of 600 | tidore
# City not found. Skipping...
# Processing Record 170 of 600 | sao filipe
# Processing Record 171 of 600 | beringovskiy
# Processing Record 172 of 600 | vangaindrano
# Processing Record 173 of 600 | tavricheskoye
# Processing Record 174 of 600 | cidreira
# Processing Record 175 of 600 | butaritari
# Processing Record 176 of 600 | sakaiminato
# Processing Record 177 of 600 | wageningen
# Processing Record 178 of 600 | sao joao da barra
# Processing Record 179 of 600 | tual
# Processing Record 180 of 600 | andenes
# Processing Record 181 of 600 | dingle
# Processing Record 182 of 600 | lugoba
# Processing Record 183 of 600 | caledon
# Processing Record 184 of 600 | mahibadhoo
# Processing Record 185 of 600 | altamont
# Processing Record 186 of 600 | rorvik
# Processing Record 187 of 600 | mahebourg
# Processing Record 188 of 600 | pevek
# Processing Record 189 of 600 | hay river
# Processing Record 190 of 600 | maumere
# Processing Record 191 of 600 | san vicente
# Processing Record 192 of 600 | bluff
# Processing Record 193 of 600 | kollumerland
# City not found. Skipping...
# Processing Record 194 of 600 | tsihombe
# City not found. Skipping...
# Processing Record 195 of 600 | davenda
# Processing Record 196 of 600 | matina
# Processing Record 197 of 600 | kaitangata
# Processing Record 198 of 600 | jiddah
# City not found. Skipping...
# Processing Record 199 of 600 | saint-pierre
# Processing Record 200 of 600 | luderitz
# Processing Record 201 of 600 | henties bay
# Processing Record 202 of 600 | esperance
# Processing Record 203 of 600 | gornopravdinsk
# Processing Record 204 of 600 | port macquarie
# Processing Record 205 of 600 | narsaq
# Processing Record 206 of 600 | mamou
# Processing Record 207 of 600 | atar
# Processing Record 208 of 600 | catarman
# Processing Record 209 of 600 | sao miguel do araguaia
# Processing Record 210 of 600 | dangriga
# Processing Record 211 of 600 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 212 of 600 | calvinia
# Processing Record 213 of 600 | angoche
# Processing Record 214 of 600 | coahuayana
# Processing Record 215 of 600 | magadan
# Processing Record 216 of 600 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 217 of 600 | xam nua
# Processing Record 218 of 600 | bathsheba
# Processing Record 219 of 600 | tabialan
# City not found. Skipping...
# Processing Record 220 of 600 | flinders
# Processing Record 221 of 600 | qasigiannguit
# Processing Record 222 of 600 | grindavik
# Processing Record 223 of 600 | togur
# Processing Record 224 of 600 | ponta do sol
# Processing Record 225 of 600 | xuddur
# Processing Record 226 of 600 | chama
# Processing Record 227 of 600 | tokat
# Processing Record 228 of 600 | dobromir
# Processing Record 229 of 600 | inhambane
# Processing Record 230 of 600 | chuy
# Processing Record 231 of 600 | atambua
# Processing Record 232 of 600 | maralal
# Processing Record 233 of 600 | kortkeros
# Processing Record 234 of 600 | mercedes
# Processing Record 235 of 600 | campbellton
# Processing Record 236 of 600 | pangnirtung
# Processing Record 237 of 600 | tumannyy
# City not found. Skipping...
# Processing Record 238 of 600 | udachnyy
# Processing Record 239 of 600 | la palma
# Processing Record 240 of 600 | san juan
# Processing Record 241 of 600 | gejiu
# Processing Record 242 of 600 | vallenar
# Processing Record 243 of 600 | mergui
# City not found. Skipping...
# Processing Record 244 of 600 | baboua
# City not found. Skipping...
# Processing Record 245 of 600 | yar-sale
# Processing Record 246 of 600 | juneau
# Processing Record 247 of 600 | faranah
# Processing Record 248 of 600 | kamenskoye
# City not found. Skipping...
# Processing Record 249 of 600 | george
# Processing Record 250 of 600 | samarai
# Processing Record 251 of 600 | ayios kirikos
# City not found. Skipping...
# Processing Record 252 of 600 | elat
# Processing Record 253 of 600 | madang
# Processing Record 254 of 600 | moroto
# Processing Record 255 of 600 | bako
# Processing Record 256 of 600 | mukhen
# Processing Record 257 of 600 | sonthofen
# Processing Record 258 of 600 | georgetown
# Processing Record 259 of 600 | autun
# Processing Record 260 of 600 | attawapiskat
# City not found. Skipping...
# Processing Record 261 of 600 | esmeralda
# Processing Record 262 of 600 | chokurdakh
# Processing Record 263 of 600 | sidrolandia
# Processing Record 264 of 600 | liverpool
# Processing Record 265 of 600 | nuuk
# Processing Record 266 of 600 | cagliliog
# Processing Record 267 of 600 | faya
# Processing Record 268 of 600 | cedar rapids
# Processing Record 269 of 600 | chengde
# Processing Record 270 of 600 | estelle
# Processing Record 271 of 600 | saleaula
# City not found. Skipping...
# Processing Record 272 of 600 | mitsamiouli
# Processing Record 273 of 600 | la libertad
# Processing Record 274 of 600 | louisbourg
# City not found. Skipping...
# Processing Record 275 of 600 | bonthe
# Processing Record 276 of 600 | great falls
# Processing Record 277 of 600 | zhovti vody
# Processing Record 278 of 600 | biak
# Processing Record 279 of 600 | te anau
# Processing Record 280 of 600 | kitimat
# Processing Record 281 of 600 | svetlogorsk
# Processing Record 282 of 600 | marsa matruh
# Processing Record 283 of 600 | ulaangom
# Processing Record 284 of 600 | itoman
# Processing Record 285 of 600 | barcelos
# Processing Record 286 of 600 | tabas
# Processing Record 287 of 600 | tilichiki
# Processing Record 288 of 600 | chickasha
# Processing Record 289 of 600 | plavinas
# Processing Record 290 of 600 | kedgwick
# Processing Record 291 of 600 | salalah
# Processing Record 292 of 600 | datong
# Processing Record 293 of 600 | palmer
# Processing Record 294 of 600 | rivadavia
# Processing Record 295 of 600 | auki
# Processing Record 296 of 600 | ribeira grande
# Processing Record 297 of 600 | hirara
# Processing Record 298 of 600 | along
# Processing Record 299 of 600 | lasa
# Processing Record 300 of 600 | bajo baudo
# City not found. Skipping...
# Processing Record 301 of 600 | zhanakorgan
# Processing Record 302 of 600 | chodavaram
# Processing Record 303 of 600 | jega
# Processing Record 304 of 600 | mareeba
# Processing Record 305 of 600 | tasiilaq
# Processing Record 306 of 600 | amderma
# City not found. Skipping...
# Processing Record 307 of 600 | sentyabrskiy
# City not found. Skipping...
# Processing Record 308 of 600 | sooke
# Processing Record 309 of 600 | shenjiamen
# Processing Record 310 of 600 | kiunga
# Processing Record 311 of 600 | estepa
# Processing Record 312 of 600 | san-pedro
# Processing Record 313 of 600 | greystones
# Processing Record 314 of 600 | ayan
# Processing Record 315 of 600 | luwuk
# Processing Record 316 of 600 | middelburg
# Processing Record 317 of 600 | tawkar
# City not found. Skipping...
# Processing Record 318 of 600 | sfantu gheorghe
# Processing Record 319 of 600 | berlevag
# Processing Record 320 of 600 | grand river south east
# City not found. Skipping...
# Processing Record 321 of 600 | yelkhovka
# Processing Record 322 of 600 | kardamaina
# Processing Record 323 of 600 | meyungs
# City not found. Skipping...
# Processing Record 324 of 600 | guilin
# Processing Record 325 of 600 | meulaboh
# Processing Record 326 of 600 | rurrenabaque
# Processing Record 327 of 600 | barra do bugres
# Processing Record 328 of 600 | yulara
# Processing Record 329 of 600 | xining
# Processing Record 330 of 600 | moron
# Processing Record 331 of 600 | gangtok
# Processing Record 332 of 600 | basco
# Processing Record 333 of 600 | kahului
# Processing Record 334 of 600 | paulo ramos
# Processing Record 335 of 600 | puerto ayora
# Processing Record 336 of 600 | tezu
# Processing Record 337 of 600 | port lincoln
# Processing Record 338 of 600 | forest hills
# Processing Record 339 of 600 | omsukchan
# Processing Record 340 of 600 | hamilton
# Processing Record 341 of 600 | beira
# Processing Record 342 of 600 | kieta
# Processing Record 343 of 600 | uvira
# Processing Record 344 of 600 | tiksi
# Processing Record 345 of 600 | ambilobe
# Processing Record 346 of 600 | mponela
# Processing Record 347 of 600 | porto nacional
# Processing Record 348 of 600 | baruun-urt
# Processing Record 349 of 600 | karatuzskoye
# City not found. Skipping...
# Processing Record 350 of 600 | hambantota
# Processing Record 564 of 600 | clyde river
# City not found. Skipping...
# Processing Record 565 of 600 | ternate
# City not found. Skipping...
# Processing Record 566 of 600 | muros
# City not found. Skipping...
# Processing Record 567 of 600 | del rio
# City not found. Skipping...
# Processing Record 568 of 600 | porosozero
# City not found. Skipping...
# Processing Record 569 of 600 | banepa
# City not found. Skipping...
# Processing Record 570 of 600 | veraval
# City not found. Skipping...
# Processing Record 571 of 600 | areosa
# City not found. Skipping...
# Processing Record 572 of 600 | sinkat
# City not found. Skipping...
# Processing Record 573 of 600 | celestun
# City not found. Skipping...
# Processing Record 574 of 600 | san jose
# City not found. Skipping...
# Processing Record 575 of 600 | hienghene
# City not found. Skipping...
# Processing Record 576 of 600 | santa rosa
# City not found. Skipping...
# Processing Record 577 of 600 | konya
# City not found. Skipping...
# Processing Record 578 of 600 | cabo san lucas
# City not found. Skipping...
# Processing Record 579 of 600 | broome
# City not found. Skipping...
# Processing Record 580 of 600 | prince rupert
# City not found. Skipping...
# Processing Record 581 of 600 | roald
# City not found. Skipping...
# Processing Record 582 of 600 | gorom-gorom
# City not found. Skipping...
# Processing Record 583 of 600 | baker city
# City not found. Skipping...
# Processing Record 584 of 600 | loukhi
# City not found. Skipping...
# Processing Record 585 of 600 | vila franca do campo
# City not found. Skipping...
# Processing Record 586 of 600 | mecca
# City not found. Skipping...
# Processing Record 587 of 600 | barra do corda
# City not found. Skipping...
# Processing Record 588 of 600 | ust-kuyga
# City not found. Skipping...
# Processing Record 589 of 600 | kattivakkam
# City not found. Skipping...
# Processing Record 590 of 600 | gravenhurst
# City not found. Skipping...
# Processing Record 591 of 600 | sorland
# City not found. Skipping...
# Processing Record 592 of 600 | sungaipenuh
# City not found. Skipping...
# Processing Record 593 of 600 | trairi
# City not found. Skipping...
# Processing Record 594 of 600 | pochutla
# City not found. Skipping...
# Processing Record 595 of 600 | murwara
# City not found. Skipping...
# Processing Record 596 of 600 | puri
# City not found. Skipping...
# Processing Record 597 of 600 | fairbanks
# City not found. Skipping...
# Processing Record 598 of 600 | monrovia
# City not found. Skipping...
# Processing Record 599 of 600 | wajima
# City not found. Skipping...
# Processing Record 600 of 600 | maroantsetra
# City not found. Skipping...

# %%
#create a copy of the data frame
cities_df_clean = cities_df

# clean data frame
cities_df_clean.replace('', np.nan, inplace=True)
cities_df_clean = cities_df_clean.dropna(how='any', inplace=False)
cities_df_clean = cities_df_clean.reset_index(drop = True)
cities_df_clean.count()

# %%
#save to CSV
cities_df_clean.to_csv(output_data_file)

#display data frame
cities_df_clean.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10112/2781670531.py in <module>
#       1 #save to CSV
# ----> 2 cities_df_clean.to_csv(output_data_file)
#       3
#       4 #display data frame
#       5 cities_df_clean.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_data/cities.csv'

# %%
x_axis = cities_df_clean["Lat"]
y_axis = cities_df_clean["Max Temp"]

plt.figure(figsize = [10,5])
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
date_code = cities_df_clean["Date"][0]
date = str(time.strftime("%D", time.localtime(int(date_code))))
title = f"City Latitude vs. Max Temperature ({date})"
plt.title(title, fontsize=14, fontweight="bold")
plt.grid(which = 'major', axis = "both")
plt.xlabel("Latitude")
plt.xlim(-80,80)
plt.ylabel("Max Temperature (F)")

# Save the Figure
plt.tight_layout()
plt.savefig("output_data/MaxTemp_Lat.png")

# Show the Figure
plt.show()

# %%
x_axis = cities_df_clean["Lat"]
y_axis = cities_df_clean["Humidity"]

plt.figure(figsize = [10,5])
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
date_code = cities_df_clean["Date"][0]
date = str(time.strftime("%D", time.localtime(int(date_code))))
title = f"City Latitude vs.Humidity ({date})"
plt.title(title, fontsize=14, fontweight="bold")
plt.grid(which = 'major', axis = "both")
plt.xlabel("Latitude")
plt.xlim(-80,80)
plt.ylabel("Humidity (%)")

# Save the Figure
plt.tight_layout()
plt.savefig("output_data/Humidity_Lat.png")

# Show the Figure
plt.show()

# %%
x_axis = cities_df_clean["Lat"]
y_axis = cities_df_clean["Cloudiness"]

plt.figure(figsize = [10,5])
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
date_code = cities_df_clean["Date"][0]
date = str(time.strftime("%D", time.localtime(int(date_code))))
title = f"City Latitude vs.Cloudiness ({date})"
plt.title(title, fontsize=14, fontweight="bold")
plt.grid(which = 'major', axis = "both")
plt.xlabel("Latitude")
plt.xlim(-80,80)
plt.ylabel("Cloudiness (%)")

# Save the Figure
plt.tight_layout()
plt.savefig("output_data/Cloudiness_Lat.png")

# Show the Figure
plt.show()

# %%
x_axis = cities_df_clean["Lat"]
y_axis = cities_df_clean["Wind Speed"]

plt.figure(figsize = [10,5])
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
date_code = cities_df_clean["Date"][0]
date = str(time.strftime("%D", time.localtime(int(date_code))))
title = f"City Latitude vs.Wind Speed ({date})"
plt.title(title, fontsize=14, fontweight="bold")
plt.grid(which = 'major', axis = "both")
plt.xlabel("Latitude")
plt.xlim(-80,80)
plt.ylabel("Wind Speed (mph)")

# Save the Figure
plt.tight_layout()
plt.savefig("output_data/WindSpeed_Lat.png")

# Show the Figure
plt.show()
